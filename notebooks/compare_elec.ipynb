# %%
import pandas as pd
import numpy as np
import os
import sys
# Verifica a estrutura
current_dir = os.getcwd()
print(f"Diretório atual: {current_dir}")

project_root = os.path.abspath('../')
print(f"Diretório raiz do projeto: {project_root}")

sys.path.insert(0, project_root)
from data import eda
# Out:
# Diretório atual: /home/henriqueramos_qs/meta-learning-concept-drift/notebooks
# Diretório raiz do projeto: /home/henriqueramos_qs/meta-learning-concept-drift

# %%
def open(notebook_dir:str, filename)-> pd.DataFrame:
    script_dir = os.getcwd()
    print(script_dir)
    path = os.path.abspath(os.path.join(script_dir, '../', 'metabase', notebook_dir, filename))
    # notebook_path = os.path.join(os.path.abspath('../metabase', notebook_dir))  
    print("path", path)
    

    if not os.path.exists(path):
        print(f"ERRO: Arquivo não encontrado em {path}")

    df = pd.read_csv(path)
    return df

# %%
df_henrique = open("fernanda_weak","basemodel: RandomForestClassifier  - dataset: electricity - with_drift_metrics.csv")
df_fernanda = open("metabases_test", "basemodel: RandomForestClassifier  - dataset: electricity - with_drift_metrics.csv")
goal_metric = "kappa"

henrique_cols = [col for col in df_henrique.columns if goal_metric in col]
print(henrique_cols)

fernanda_cols = [col for col in df_fernanda.columns if goal_metric in col]
fernanda_cols = [col for col in fernanda_cols if col in henrique_cols]
fernanda_cols=["last_kappa"]
df_henrique = df_henrique[fernanda_cols]
df_fernanda = df_fernanda[fernanda_cols]
# Out:
#   Cell In[39], line 10
#     fernanda_cols=[]"last_kappa"]
#                                 ^
# SyntaxError: unmatched ']'

# %%
eda.EDA.make(df_fernanda)
# Out:
# ================================================================================
# Exploratory Data Analysis
# ================================================================================
#
# 1. Basic Information
# Dataset dimensions: (1424,)
#
# Data types:
# /home/henriqueramos_qs/meta-learning-concept-drift/data/utils/eda.py:88: SyntaxWarning: invalid escape sequence '\C'
#   print(f"\Column: {col}")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 eda.EDA.make(df_fernanda)
#
# File ~/meta-learning-concept-drift/data/utils/eda.py:60, in EDA.make(df, sample_size)
#      58 print(f"Dataset dimensions: {df.shape} ")
#      59 print("\nData types:")
# ---> 60 print(df.dtypes.to_string())
#      62 ## 2. Data sampling
#      63 print("\n2. Data sampling")
#
# AttributeError: 'numpy.dtypes.Float64DType' object has no attribute 'to_string'

# %%
eda.EDA.make(df_henrique)

df_henrique.head(100)
# Out:
# ================================================================================
# Exploratory Data Analysis
# ================================================================================
#
# 1. Basic Information
# Dataset dimensions: (1424,)
#
# Data types:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 eda.EDA.make(df_henrique)
#       3 df_henrique.head(100)
#
# File ~/meta-learning-concept-drift/data/utils/eda.py:60, in EDA.make(df, sample_size)
#      58 print(f"Dataset dimensions: {df.shape} ")
#      59 print("\nData types:")
# ---> 60 print(df.dtypes.to_string())
#      62 ## 2. Data sampling
#      63 print("\n2. Data sampling")
#
# AttributeError: 'numpy.dtypes.Float64DType' object has no attribute 'to_string'
